# %% [markdown]
# # Notebook onde analizaremos quais são os atributos relevantes

# %%
import numpy as np
import pandas as pd # importando a lib pandas para armazenar os dados
import matplotlib.pyplot as plt # importando a bib matplotlib para visualizar os dados em gráficos
import seaborn as sb # important a lib seaborn para visualização de gráficos

# Base de dados baixada a partir do Kaggle: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud?resource=download
df = pd.read_csv('../Bases/creditcard.csv')

df.head()

data = df.to_numpy()

legitimos = data[data[:,30] == 0]
fraudes = data[data[:,30] == 1]

print(len(legitimos))
print(len(fraudes))

colunas = {"Time": 0,
           "A1": 1,
           "A2": 2,
           "A3": 3,
           "A4": 4,
           "A5": 5,
           "A6": 6,
           "A7": 7,
           "A8": 8,
           "A9": 9,
           "A10": 10,
           "A11": 11,
           "A12": 12,
           "A13": 13,
           "A14": 14,
           "A15": 15,
           "A16": 16,
           "A17": 17,
           "A18": 18,
           "A19": 19,
           "A20": 20,
           "A21": 21,
           "A22": 22,
           "A23": 23,
           "A24": 24,
           "A25": 25,
           "A26": 26,
           "A27": 27,
           "A28": 28,
           "Amount": 29,
           "Classe": 30}
# Out:
# 284315
# 492

# %% [markdown]
# ## Abaixo plotaremos as colunas comparando as com a classe

# %% [markdown]
# ### Time

# %%
# Plotando a coluna "Time" com a "Class"

plt.plot(legitimos[:, colunas['Time']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['Time']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['Time']], fraudes[:, colunas['Time']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A1

# %%
# Plotando a coluna "A1" com a "Class"

plt.plot(legitimos[:, colunas['A1']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A1']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A1']], fraudes[:, colunas['A1']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A2

# %%
# Plotando a coluna "A2" com a "Class"

plt.plot(legitimos[:, colunas['A2']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A2']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A2']], fraudes[:, colunas['A2']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A3

# %%
# Plotando a coluna "A3" com a "Class"

plt.plot(legitimos[:, colunas['A3']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A3']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A3']], fraudes[:, colunas['A3']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A4

# %%
# Plotando a coluna "A4" com a "Class"

plt.plot(legitimos[:, colunas['A4']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A4']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A4']], fraudes[:, colunas['A4']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A5

# %%
# Plotando a coluna "A5" com a "Class"

plt.plot(legitimos[:, colunas['A5']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A5']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A5']], fraudes[:, colunas['A5']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A6

# %%
# Plotando a coluna "A6" com a "Class"

plt.plot(legitimos[:, colunas['A6']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A6']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A6']], fraudes[:, colunas['A6']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A7

# %%
# Plotando a coluna "A7" com a "Class"

plt.plot(legitimos[:, colunas['A7']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A7']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A7']], fraudes[:, colunas['A7']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A8

# %%
# Plotando a coluna "A8" com a "Class"

plt.plot(legitimos[:, colunas['A8']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A8']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A8']], fraudes[:, colunas['A8']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A9

# %%
# Plotando a coluna "A9" com a "Class"

plt.plot(legitimos[:, colunas['A9']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A9']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A9']], fraudes[:, colunas['A9']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A10

# %%
# Plotando a coluna "A10" com a "Class"

plt.plot(legitimos[:, colunas['A10']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A10']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A10']], fraudes[:, colunas['A10']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A11

# %%
# Plotando a coluna "A11" com a "Class"

plt.plot(legitimos[:, colunas['A11']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A11']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A11']], fraudes[:, colunas['A11']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A12

# %%
# Plotando a coluna "A12" com a "Class"

plt.plot(legitimos[:, colunas['A12']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A12']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A12']], fraudes[:, colunas['A12']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A13

# %%
# Plotando a coluna "A13" com a "Class"

plt.plot(legitimos[:, colunas['A13']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A13']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A13']], fraudes[:, colunas['A13']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A14

# %%
# Plotando a coluna "A14" com a "Class"

plt.plot(legitimos[:, colunas['A14']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A14']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A14']], fraudes[:, colunas['A14']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A15

# %%
# Plotando a coluna "A15" com a "Class"

plt.plot(legitimos[:, colunas['A15']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A15']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A15']], fraudes[:, colunas['A15']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A16

# %%
# Plotando a coluna "A16" com a "Class"

plt.plot(legitimos[:, colunas['A16']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A16']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A16']], fraudes[:, colunas['A16']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A17

# %%
# Plotando a coluna "A17" com a "Class"

plt.plot(legitimos[:, colunas['A17']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A17']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A17']], fraudes[:, colunas['A17']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A18

# %%
# Plotando a coluna "A18" com a "Class"

plt.plot(legitimos[:, colunas['A18']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A18']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A18']], fraudes[:, colunas['A18']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A19

# %%
# Plotando a coluna "A19" com a "Class"

plt.plot(legitimos[:, colunas['A19']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A19']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A19']], fraudes[:, colunas['A19']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A20

# %%
# Plotando a coluna "A20" com a "Class"

plt.plot(legitimos[:, colunas['A20']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A20']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A20']], fraudes[:, colunas['A20']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A21

# %%
# Plotando a coluna "A21" com a "Class"

plt.plot(legitimos[:, colunas['A21']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A21']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A21']], fraudes[:, colunas['A21']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A22

# %%
# Plotando a coluna "A22" com a "Class"

plt.plot(legitimos[:, colunas['A22']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A22']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A22']], fraudes[:, colunas['A22']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A23

# %%
# Plotando a coluna "A23" com a "Class"

plt.plot(legitimos[:, colunas['A23']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A23']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A23']], fraudes[:, colunas['A23']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A24

# %%
# Plotando a coluna "A24" com a "Class"

plt.plot(legitimos[:, colunas['A24']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A24']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A24']], fraudes[:, colunas['A24']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A25

# %%
# Plotando a coluna "A25" com a "Class"

plt.plot(legitimos[:, colunas['A25']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A25']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A25']], fraudes[:, colunas['A25']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A26

# %%
# Plotando a coluna "A26" com a "Class"

plt.plot(legitimos[:, colunas['A26']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A26']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A26']], fraudes[:, colunas['A26']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A27

# %%
# Plotando a coluna "A27" com a "Class"

plt.plot(legitimos[:, colunas['A27']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A27']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A27']], fraudes[:, colunas['A27']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### A28

# %%
# Plotando a coluna "A28" com a "Class"

plt.plot(legitimos[:, colunas['A28']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['A28']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['A28']], fraudes[:, colunas['A28']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### Amount

# %%
# Plotando a coluna "Amount" com a "Class"

plt.plot(legitimos[:, colunas['Amount']], legitimos[:, colunas['Classe']], 'ob', label="Legitimos")
plt.plot(fraudes[:, colunas['Amount']], fraudes[:, colunas['Classe']], 'or', label="Fraudes")
plt.legend(bbox_to_anchor=(1.3, 1))
plt.show()

violinos = plt.violinplot([legitimos[:, colunas['Amount']], fraudes[:, colunas['Amount']]], showmeans=True);
cores = ['Blue', 'Red']

for pc, cor in zip(violinos['bodies'], cores):
    pc.set_facecolor(cor)

plt.legend(['Legitimos', 'Fraudes'], loc='center')
plt.show()

# %% [markdown]
# ### Parallel line plot

# %%
# Plotando a coluna "A20" com a "Class"

plt.figure(figsize=(10,10))

cFraude = fraudes[:, 1:]
cFraude = cFraude[:, :-2]

cLegitimo = legitimos[:, 1:]
cLegitimo = cLegitimo[:, :-2]


for i in cFraude:
    plt.plot(i, '-r', label="Fraudes")

for i in cLegitimo:
    plt.plot(i, '-b', label="Legitimos")

plt.show()

# %% [markdown]
# ## Heat Map

# %%
# Usando o pandas dataframe
corr_matrix = df.corr()
sb.heatmap(corr_matrix, annot=False, cmap='coolwarm')
# Out:
# <Axes: >
